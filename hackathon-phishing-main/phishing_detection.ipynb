# %%
# !pip install pandas
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

# List of all your CSV file paths
csv_files = ['mail_data.csv']  # Add your files here

# Read and concatenate them
raw_mail_data = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)

# Preview
print(raw_mail_data.head())
print("Total samples:", len(raw_mail_data))
# Out:
#      Category                                            Message
# 0  legitimate  Go until jurong point, crazy.. Available only ...
# 1  legitimate                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  legitimate  U dun say so early hor... U c already then say...
# 4  legitimate  Nah I don't think he goes to usf, he lives aro...
# Total samples: 5572

# %%
raw_mail_data = pd.read_csv('mail_data.csv')

# %%
# import pandas as pd

# # Read the keywords from the file
# with open('sample_word.txt', 'r', encoding='utf-8') as f:
#     lines = f.readlines()

# # Remove empty lines and whitespace
# keywords = [line.strip() for line in lines if line.strip()]

# # Create a DataFrame
# df = pd.DataFrame(keywords, columns=["keyword"])

# # Save as CSV
# df.to_csv("spam_keywords.csv", index=False)

# print("CSV file 'spam_keywords.csv' created successfully!")

# %%
# print(X_train.columns)

# %%
print(raw_mail_data)
# Out:
#         Category                                            Message
# 0     legitimate  Go until jurong point, crazy.. Available only ...
# 1     legitimate                      Ok lar... Joking wif u oni...
# 2           spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3     legitimate  U dun say so early hor... U c already then say...
# 4     legitimate  Nah I don't think he goes to usf, he lives aro...
# ...          ...                                                ...
# 5567        spam  This is the 2nd time we have tried 2 contact u...
# 5568  legitimate               Will ü b going to esplanade fr home?
# 5569  legitimate  Pity, * was in mood for that. So...any other s...
# 5570  legitimate  The guy did some bitching but I acted like i'd...
# 5571  legitimate                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
mail_data = raw_mail_data.where((pd.notnull(raw_mail_data)),'')

# %%
mail_data.head()
# Out:
#      Category                                            Message
# 0  legitimate  Go until jurong point, crazy.. Available only ...
# 1  legitimate                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  legitimate  U dun say so early hor... U c already then say...
# 4  legitimate  Nah I don't think he goes to usf, he lives aro...

# %%
mail_data.shape
# Out:
# (5572, 2)

# %%
mail_data.loc[mail_data['Category'] == 'spam', 'Category',] = 0
mail_data.loc[mail_data['Category'] == 'legitimate', 'Category',] = 1

# %%
X = mail_data['Message']

Y = mail_data['Category']

# %%
print(X)
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %%
# transform the text data to feature vectors that can be used as input to the Logistic regression

feature_extraction = TfidfVectorizer(min_df = 1, stop_words='english', lowercase=True)

X_train_features = feature_extraction.fit_transform(X_train)
X_test_features = feature_extraction.transform(X_test)

# convert Y_train and Y_test values as integers

Y_train = Y_train.astype('int')
Y_test = Y_test.astype('int')

# %%
print(X_train)
# Out:
# 3075                  Don know. I did't msg him recently.
# 1787    Do you know why god created gap between your f...
# 1614                         Thnx dude. u guys out 2nite?
# 4304                                      Yup i'm free...
# 3266    44 7732584351, Do you want a New Nokia 3510i c...
#                               ...
# 789     5 Free Top Polyphonic Tones call 087018728737,...
# 968     What do u want when i come back?.a beautiful n...
# 1667    Guess who spent all last night phasing in and ...
# 3321    Eh sorry leh... I din c ur msg. Not sad alread...
# 1688    Free Top ringtone -sub to weekly ringtone-get ...
# Name: Message, Length: 4457, dtype: object

# %%
print(X_train_features)
# Out:
#   (0, 2329)	0.38783870336935383
#   (0, 3808)	0.34780165336891333
#   (0, 2224)	0.413103377943378
#   (0, 4456)	0.4168658090846482
#   (0, 5413)	0.6198254967574347
#   (1, 3808)	0.17419952275504033
#   (1, 3046)	0.2503712792613518
#   (1, 1991)	0.33036995955537024
#   (1, 2956)	0.33036995955537024
#   (1, 2758)	0.3226407885943799
#   (1, 1839)	0.2784903590561455
#   (1, 918)	0.22871581159877646
#   (1, 2746)	0.3398297002864083
#   (1, 2957)	0.3398297002864083
#   (1, 3322)	0.31610586766078863
#   (1, 3182)	0.29694482957694585
#   (1, 4080)	0.18880584110891163
#   (2, 6601)	0.6056811524587518
#   (2, 2404)	0.45287711070606745
#   (2, 3156)	0.4107239318312698
#   (2, 407)	0.509272536051008
#   (3, 7414)	0.8100020912469564
#   (3, 2870)	0.5864269879324768
#   (4, 2870)	0.41872147309323743
#   (4, 487)	0.2899118421746198
#   :	:
#   (4454, 2855)	0.47210665083641806
#   (4454, 2246)	0.47210665083641806
#   (4455, 4456)	0.24920025316220423
#   (4455, 3922)	0.31287563163368587
# ...

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression model with the training data
model.fit(X_train_features, Y_train)
# Out:
# LogisticRegression()

# %%
# prediction on training data

prediction_on_training_data = model.predict(X_train_features)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

# %%
print('Accuracy on training data : ', accuracy_on_training_data)
# Out:
# Accuracy on training data :  0.9676912721561588

# %%
# prediction on test data

prediction_on_test_data = model.predict(X_test_features)
accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)

# %%
print('Accuracy on test data : ', accuracy_on_test_data)
# Out:
# Accuracy on test data :  0.9659192825112107

# %%
input_mail = ["Sorry, I'll call later"]

# convert text to feature vectors
input_data_features = feature_extraction.transform(input_mail)

# making prediction

prediction = model.predict(input_data_features)
print(prediction)


if (prediction[0]==1):
  print('legitimate mail')
    
else:
  print('Spam mail')
# Out:
# [1]
# legitimate mail

# %%
print(feature_extraction.vocabulary_.get("congratulations"))  # Should return index or None
# Out:
# 1895

# %%
import joblib

joblib.dump(model, "model.pkl")
joblib.dump(TfidfVectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']

# %%
import joblib

# Save trained model
joblib.dump(model, "ai_detector_model.pkl")

# Save the vectorizer (TF-IDF, etc.)
joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import joblib
#       3 # Save trained model
#       4 joblib.dump(model, "ai_detector_model.pkl")
#
# ModuleNotFoundError: No module named 'joblib'

# %%
from fastapi import FastAPI, Form
from fastapi.middleware.cors import CORSMiddleware
import joblib

# Load your model and vectorizer
model = joblib.load("ai_detector_model.pkl")
vectorizer = joblib.load("vectorizer.pkl")

# Initialize API app
app = FastAPI()

# Allow frontend to access API (CORS)
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # for development use
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

@app.post("/predict")
def predict(email: str = Form(...)):
    X = vectorizer.transform([email])
    pred = model.predict(X)[0]
    confidence = max(model.predict_proba(X)[0])
    return {"label": pred, "confidence": round(confidence, 2)}
